# %%
from scipy.stats import multivariate_normal, norm, poisson, gamma
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
from CopulaGenerator import CopulaGenerator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cop = CopulaGenerator()
u_x, u_y = cop.Clayton(8.5, (1000,))
plt.plot(u_y, u_x, 'x')

# %%
b = cop.generate_data([u_x, u_y])
b.shape
# Out:
# modifying the file
# (1000,)

# %%
sec_u_x, sec_u_y = cop.Clayton(2.5)
plt.plot(sec_u_x, sec_u_y, 'x')

# %%
data = cop.generate_data([sec_u_x, sec_u_y])
data[:10]
# Out:
# array([8., 6., 4., 8., 6., 2., 7., 3., 6., 4.])

# %%
frank_cop = CopulaGenerator()
u_x_f, u_y_f = frank_cop.frank2d(4.5, (10000,))
plt.plot(u_x, u_y, 'x')
# Out:
# /content/CopulaGenerator.py:58: RuntimeWarning: invalid value encountered in log1p
#   u2 = -1/self.alpha * np.log1p(numerator/denominator)

# %%
frank_cop.generate_data([u_x_f, u_y_f])[:10]
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:3184: RuntimeWarning: invalid value encountered in greater
#   cond1 = (q > 0) & (q < 1)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:3184: RuntimeWarning: invalid value encountered in less
#   cond1 = (q > 0) & (q < 1)
# array([4., 6., 3., 4., 8., 7., 6., 6., 8., 3.])

# %%
gumbel_cop = CopulaGenerator()
u_x_g, u_y_g = gumbel_cop.Gumbel(8.5, (10000))
plt.plot(u_x_g, u_y_g, 'x')

# %%
gumbel_cop.generate_data([u_x_f, u_y_f])[:10]
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:3184: RuntimeWarning: invalid value encountered in greater
#   cond1 = (q > 0) & (q < 1)
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py:3184: RuntimeWarning: invalid value encountered in less
#   cond1 = (q > 0) & (q < 1)
# array([4., 5., 3., 4., 8., 7., 6., 6., 8., 3.])
