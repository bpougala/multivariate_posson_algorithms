# %%
from scipy.stats import multivariate_normal, norm, poisson, gamma
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
from CopulaGenerator import CopulaGenerator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cop = CopulaGenerator()
u_x, u_y = cop.Clayton(8.5, (1000,))
plt.plot(u_y, u_x, 'x')

# %%
b = cop.generate_data([u_x, u_y])
b.shape
# Out:
# modifying the file
# (1000,)

# %%
sec_u_x, sec_u_y = cop.Clayton(11.5)
plt.plot(sec_u_x, sec_u_y, 'x')

# %%
data = cop.generate_data([sec_u_x, sec_u_y])
data[:10]
# Out:
# array([8., 6., 4., 8., 6., 2., 7., 3., 6., 4.])

# %%
frank_cop = CopulaGenerator()
u_x_f, u_y_f = frank_cop.frank2d(4.5, (10000,))
plt.plot(u_x, u_y, 'x')
# Out:
# /content/CopulaGenerator.py:61: RuntimeWarning: invalid value encountered in log1p
#   u2 = -1/self.alpha * np.log1p(numerator/denominator)

# %%
frank_cop.generate_data([u_x_f, u_y_f])[:10]
# Out:
# calling removeNans
# array([4., 5., 4., 4., 8., 7., 6., 6., 7., 4.])

# %%
gumbel_cop = CopulaGenerator()
u_x_g, u_y_g = gumbel_cop.Gumbel(8.5, (10000))
plt.plot(u_x_g, u_y_g, 'x')

# %%
gumbel_cop.generate_data([u_x_f, u_y_f])
# Out:
# calling removeNans
# array([1., 2., 1., ..., 2., 2., 3.])

# %%
cp = cop.MultiDimensionalClayton(8.5)
len(cp)
# Out:
# Size of u_x: (1000,)
# Size of arr: 1
# Size of u_x: (1000,)
# Size of arr: 2
# 2

# %%
u_x = cp[0] 
u_y = cp[1]
print(u_x.shape)
plt.plot(u_x, u_y, 'x')
# Out:
# (1000,)
