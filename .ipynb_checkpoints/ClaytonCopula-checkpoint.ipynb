# %%
from scipy.stats import multivariate_normal, norm, poisson, gamma
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
from CopulaGenerator import CopulaGenerator as cpg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cop = CopulaGenerator()
u_x, u_y = cop.Clayton(8.5, (1000,))
plt.plot(u_x, u_y, 'x')

# %%
b = cop.generate_data([u_x, u_y])
b.shape
# Out:
# (1000,)

# %%
sec_u_x, sec_u_y = cop.Clayton(4.5)
plt.plot(sec_u_x, sec_u_y, 'x')

# %%
cop.generate_data([sec_u_x, sec_u_y])[:10]
# Out:
# array([ 4.,  4.,  3., 13.,  3.,  4.,  6.,  9.,  3.,  9.])

# %%
frank_cop = CopulaGenerator()
u_x_f, u_y_f = cop.Frank(0.02, (800,))
plt.plot(u_x, u_y, 'x')

# %%
frank_cop.generate_data([u_x_f, u_y_f])[:10]
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])
